% %% [markdown]
% ## Webcam Test

% %%
camList = webcamlist
% Out:
% camList =
%
%   1x1 cell 배열
%
%     {'Integrated Camera'}

% %%
% Connect to the webcam.
cam = webcam(1)
% Out:
% cam =
%
%   webcam - 속성 있음:
%
%                      Name: 'Integrated Camera'
%      AvailableResolutions: {'640x480'  '320x180'  '320x240'  '352x288'  '424x240'  '640x360'  '848x480'  '960x540'  '1280x720'}
%                Resolution: '640x480'
%              ExposureMode: 'auto'
%               ColorEnable: 1
%          WhiteBalanceMode: 'auto'
%                      Tilt: 0
%                     Gamma: 120
%                      Zoom: 100
%                  Exposure: -6
%                Brightness: 128
%              WhiteBalance: 4600
%                 Sharpness: 0
%                       Hue: 0
%                  Contrast: 32
%                Saturation: 64
%                      Roll: 0
%     BacklightCompensation: 1
%                       Pan: 0

% %%
preview(cam);

% %%
img = snapshot(cam);

% %%
% Display the frame in a figure window.
image(img);

% %%
for idx = 1:5
    img = snapshot(cam);
    image(img);
end

% %%
clear cam

% %% [markdown]
% ## AlexNet

% %%
% Copyright 2016 The MathWorks, Inc.

clear

camera = webcam; % Connect to the camera
nnet = alexnet;  % Load the neural net

while true   
    picture = camera.snapshot;              % Take a picture    
    picture = imresize(picture,[227,227]);  % Resize the picture

    label = classify(nnet, picture);        % Classify the picture
       
    image(picture);     % Show the picture
    title(char(label)); % Show the label
    drawnow;   
end

% %%
clear cam;
